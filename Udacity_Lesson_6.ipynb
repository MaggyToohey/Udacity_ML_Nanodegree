# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import os
import numpy as np
import random
import string
import tensorflow as tf
import zipfile
from six.moves import range
from six.moves.urllib.request import urlretrieve

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  with zipfile.ZipFile(filename) as f:
    name = f.namelist()[0]
    data = tf.compat.as_str(f.read(name))
  return data
  
text = read_data(filename)
print('Data size %d' % len(text))
# Out:
# Data size 100000000

# %%
valid_size = 1000
valid_text = text[:valid_size]
train_text = text[valid_size:]
train_size = len(train_text)
print(train_size, train_text[:64])
print(valid_size, valid_text[:64])
# Out:
# 99999000 ons anarchists advocate social relations based upon voluntary as
# 1000  anarchism originated as a term of abuse first used against earl

# %%
vocabulary_size = len(string.ascii_lowercase) + 1 # [a-z] + ' '
first_letter = ord(string.ascii_lowercase[0])

def char2id(char):
  if char in string.ascii_lowercase:
    return ord(char) - first_letter + 1
  elif char == ' ':
    return 0
  else:
    print('Unexpected character: %s' % char)
    return 0
  
def id2char(dictid):
  if dictid > 0:
    return chr(dictid + first_letter - 1)
  else:
    return ' '

print(char2id('a'), char2id('z'), char2id(' '), char2id('ï'))
print(id2char(1), id2char(26), id2char(0))
# Out:
# Unexpected character: ï
# 1 26 0 0
# a z

# %%
batch_size=64
num_unrollings=10

class BatchGenerator(object):
  def __init__(self, text, batch_size, num_unrollings):
    self._text = text
    self._text_size = len(text)
    self._batch_size = batch_size
    self._num_unrollings = num_unrollings
    segment = self._text_size // batch_size
    self._cursor = [ offset * segment for offset in range(batch_size)]
    self._last_batch = self._next_batch()
  
  def _next_batch(self):
    """Generate a single batch from the current cursor position in the data."""
    batch = np.zeros(shape=(self._batch_size, vocabulary_size), dtype=np.float)
    for b in range(self._batch_size):
      batch[b, char2id(self._text[self._cursor[b]])] = 1.0
      self._cursor[b] = (self._cursor[b] + 1) % self._text_size
    return batch
  
  def next(self):
    """Generate the next array of batches from the data. The array consists of
    the last batch of the previous array, followed by num_unrollings new ones.
    """
    batches = [self._last_batch]
    for step in range(self._num_unrollings):
      batches.append(self._next_batch())
    self._last_batch = batches[-1]
    return batches

def characters(probabilities):
  """Turn a 1-hot encoding or a probability distribution over the possible
  characters back into its (most likely) character representation."""
  return [id2char(c) for c in np.argmax(probabilities, 1)]

def batches2string(batches):
  """Convert a sequence of batches back into their (most likely) string
  representation."""
  s = [''] * batches[0].shape[0]
  for b in batches:
    s = [''.join(x) for x in zip(s, characters(b))]
  return s

train_batches = BatchGenerator(train_text, batch_size, num_unrollings)
valid_batches = BatchGenerator(valid_text, 1, 1)

print(batches2string(train_batches.next()))
print(batches2string(train_batches.next()))
print(batches2string(valid_batches.next()))
print(batches2string(valid_batches.next()))
# Out:
# ['ons anarchi', 'when milita', 'lleria arch', ' abbeys and', 'married urr', 'hel and ric', 'y and litur', 'ay opened f', 'tion from t', 'migration t', 'new york ot', 'he boeing s', 'e listed wi', 'eber has pr', 'o be made t', 'yer who rec', 'ore signifi', 'a fierce cr', ' two six ei', 'aristotle s', 'ity can be ', ' and intrac', 'tion of the', 'dy to pass ', 'f certain d', 'at it will ', 'e convince ', 'ent told hi', 'ampaign and', 'rver side s', 'ious texts ', 'o capitaliz', 'a duplicate', 'gh ann es d', 'ine january', 'ross zero t', 'cal theorie', 'ast instanc', ' dimensiona', 'most holy m', 't s support', 'u is still ', 'e oscillati', 'o eight sub', 'of italy la', 's the tower', 'klahoma pre', 'erprise lin', 'ws becomes ', 'et in a naz', 'the fabian ', 'etchy to re', ' sharman ne', 'ised empero', 'ting in pol', 'd neo latin', 'th risky ri', 'encyclopedi', 'fense the a', 'duating fro', 'treet grid ', 'ations more', 'appeal of d', 'si have mad']
# ['ists advoca', 'ary governm', 'hes nationa', 'd monasteri', 'raca prince', 'chard baer ', 'rgical lang', 'for passeng', 'the nationa', 'took place ', 'ther well k', 'seven six s', 'ith a gloss', 'robably bee', 'to recogniz', 'ceived the ', 'icant than ', 'ritic of th', 'ight in sig', 's uncaused ', ' lost as in', 'cellular ic', 'e size of t', ' him a stic', 'drugs confu', ' take to co', ' the priest', 'im to name ', 'd barred at', 'standard fo', ' such as es', 'ze on the g', 'e of the or', 'd hiver one', 'y eight mar', 'the lead ch', 'es classica', 'ce the non ', 'al analysis', 'mormons bel', 't or at lea', ' disagreed ', 'ing system ', 'btypes base', 'anguages th', 'r commissio', 'ess one nin', 'nux suse li', ' the first ', 'zi concentr', ' society ne', 'elatively s', 'etworks sha', 'or hirohito', 'litical ini', 'n most of t', 'iskerdoo ri', 'ic overview', 'air compone', 'om acnm acc', ' centerline', 'e than any ', 'devotional ', 'de such dev']
# [' a']
# ['an']

# %%
def logprob(predictions, labels):
  """Log-probability of the true labels in a predicted batch."""
  predictions[predictions < 1e-10] = 1e-10
  return np.sum(np.multiply(labels, -np.log(predictions))) / labels.shape[0]

def sample_distribution(distribution):
  """Sample one element from a distribution assumed to be an array of normalized
  probabilities.
  """
  r = random.uniform(0, 1)
  s = 0
  for i in range(len(distribution)):
    s += distribution[i]
    if s >= r:
      return i
  return len(distribution) - 1

def sample(prediction):
  """Turn a (column) prediction into 1-hot encoded samples."""
  p = np.zeros(shape=[1, vocabulary_size], dtype=np.float)
  p[0, sample_distribution(prediction[0])] = 1.0
  return p

def random_distribution():
  """Generate a random column of probabilities."""
  b = np.random.uniform(0.0, 1.0, size=[1, vocabulary_size])
  return b/np.sum(b, 1)[:,None]

# %%
num_nodes = 64

graph = tf.Graph()
with graph.as_default():
  
  # Parameters:
  # Input gate: input, previous output, and bias.
  ix = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ib = tf.Variable(tf.zeros([1, num_nodes]))
  # Forget gate: input, previous output, and bias.
  fx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  fm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  fb = tf.Variable(tf.zeros([1, num_nodes]))
  # Memory cell: input, state and bias.                             
  cx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  cb = tf.Variable(tf.zeros([1, num_nodes]))
  # Output gate: input, previous output, and bias.
  ox = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ob = tf.Variable(tf.zeros([1, num_nodes]))
  # Variables saving state across unrollings.
  saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  # Classifier weights and biases.
  w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
  b = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Definition of the cell computation.
  def lstm_cell(i, o, state):
    """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
    Note that in this formulation, we omit the various connections between the
    previous state and the gates."""
    input_gate = tf.sigmoid(tf.matmul(i, ix) + tf.matmul(o, im) + ib)
    forget_gate = tf.sigmoid(tf.matmul(i, fx) + tf.matmul(o, fm) + fb)
    update = tf.matmul(i, cx) + tf.matmul(o, cm) + cb
    state = forget_gate * state + input_gate * tf.tanh(update)
    output_gate = tf.sigmoid(tf.matmul(i, ox) + tf.matmul(o, om) + ob)
    return output_gate * tf.tanh(state), state

  # Input data.
  train_data = list()
  for _ in range(num_unrollings + 1):
    train_data.append(
      tf.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
  train_inputs = train_data[:num_unrollings]
  train_labels = train_data[1:]  # labels are inputs shifted by one time step.

  # Unrolled LSTM loop.
  outputs = list()
  output = saved_output
  state = saved_state
  for i in train_inputs:
    output, state = lstm_cell(i, output, state)
    outputs.append(output)

  # State saving across unrollings.
  with tf.control_dependencies([saved_output.assign(output),
                                saved_state.assign(state)]):
    # Classifier.
    logits = tf.nn.xw_plus_b(tf.concat(outputs, 0), w, b)
    loss = tf.reduce_mean(
      tf.nn.softmax_cross_entropy_with_logits_v2(
        labels=tf.concat(train_labels, 0), logits=logits))

  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(
    10.0, global_step, 5000, 0.1, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate)
  gradients, v = zip(*optimizer.compute_gradients(loss))
  gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
  optimizer = optimizer.apply_gradients(
    zip(gradients, v), global_step=global_step)

  # Predictions.
  train_prediction = tf.nn.softmax(logits)
  
  # Sampling and validation eval: batch 1, no unrolling.
  sample_input = tf.placeholder(tf.float32, shape=[1, vocabulary_size])
  saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
  saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
  reset_sample_state = tf.group(
    saved_sample_output.assign(tf.zeros([1, num_nodes])),
    saved_sample_state.assign(tf.zeros([1, num_nodes])))
  sample_output, sample_state = lstm_cell(
    sample_input, saved_sample_output, saved_sample_state)
  with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
    sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))

# %%
num_steps = 7001
summary_frequency = 100

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  mean_loss = 0
  for step in range(num_steps):
    batches = train_batches.next()
    feed_dict = dict()
    for i in range(num_unrollings + 1):
      feed_dict[train_data[i]] = batches[i]
    _, l, predictions, lr = session.run(
      [optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
    mean_loss += l
    if step % summary_frequency == 0:
      if step > 0:
        mean_loss = mean_loss / summary_frequency
      # The mean loss is an estimate of the loss over the last few batches.
      print(
        'Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
      mean_loss = 0
      labels = np.concatenate(list(batches)[1:])
      print('Minibatch perplexity: %.2f' % float(
        np.exp(logprob(predictions, labels))))
      if step % (summary_frequency * 10) == 0:
        # Generate some samples.
        print('=' * 80)
        for _ in range(5):
          feed = sample(random_distribution())
          sentence = characters(feed)[0]
          reset_sample_state.run()
          for _ in range(79):
            prediction = sample_prediction.eval({sample_input: feed})
            feed = sample(prediction)
            sentence += characters(feed)[0]
          print(sentence)
        print('=' * 80)
      # Measure validation set perplexity.
      reset_sample_state.run()
      valid_logprob = 0
      for _ in range(valid_size):
        b = valid_batches.next()
        predictions = sample_prediction.eval({sample_input: b[0]})
        valid_logprob = valid_logprob + logprob(predictions, b[1])
      print('Validation set perplexity: %.2f' % float(np.exp(
        valid_logprob / valid_size)))
# Out:
# Initialized
# Average loss at step 0: 3.297171 learning rate: 10.000000
# Minibatch perplexity: 27.04
# ================================================================================
# befdqaiybnfeysr nisefnpi gdos y lnouyieg ifxki ot ngobcaaigbdmly imnbr aolohlsit
# itgr  iatnnem  qun a sgo xadozehxmaojb emspiioqwsxipdgppdeni l obznld  fet nwast
# qfbgeye og lhsumki oo i cootbfqqwywhigo tvherhpyrh eoaygxf xpqakddnij vcfphxloi
# qjaxw  duetcrrcdsq zaklyako vttieudidm wyx csrr rhmcuwwrjrdvrliwxplkdilsikee jdb
# ndhabiydc fitct egslpev eoi ssg meikescqhzboos qtnxt aeigdonggc iesdek le op vbo
# ================================================================================
# Validation set perplexity: 20.24
# Average loss at step 100: 2.603444 learning rate: 10.000000
# Minibatch perplexity: 11.52
# Validation set perplexity: 10.67
# Average loss at step 200: 2.246032 learning rate: 10.000000
# Minibatch perplexity: 8.41
# Validation set perplexity: 8.37
# Average loss at step 300: 2.095172 learning rate: 10.000000
# Minibatch perplexity: 7.42
# Validation set perplexity: 8.10
# Average loss at step 400: 1.996217 learning rate: 10.000000
# Minibatch perplexity: 7.55
# Validation set perplexity: 7.82
# Average loss at step 500: 1.932899 learning rate: 10.000000
# Minibatch perplexity: 6.53
# Validation set perplexity: 7.14
# Average loss at step 600: 1.906591 learning rate: 10.000000
# Minibatch perplexity: 6.28
# Validation set perplexity: 6.96
# Average loss at step 700: 1.858066 learning rate: 10.000000
# Minibatch perplexity: 6.55
# Validation set perplexity: 6.59
# Average loss at step 800: 1.813399 learning rate: 10.000000
# Minibatch perplexity: 5.85
# Validation set perplexity: 6.53
# Average loss at step 900: 1.824097 learning rate: 10.000000
# Minibatch perplexity: 6.83
# Validation set perplexity: 6.34
# Average loss at step 1000: 1.817712 learning rate: 10.000000
# Minibatch perplexity: 5.61
# ================================================================================
# jo neathini to etrecleding is cenedly cearlation geer org us of deenfletwh dinge
# for have ruder degallive affersations senationely tepperation of arr he infrumar
# wist zero its of senter and redecfed for putsolon are segferal caiting mecordbil
# ing priss yeaturional ataean the very the enccle among ty in whil the liailiignd
# ver mure eight eqouss the troint white two kqur of of excessia seme six the the
# ================================================================================
# Validation set perplexity: 6.15
# Average loss at step 1100: 1.769835 learning rate: 10.000000
# Minibatch perplexity: 5.51
# Validation set perplexity: 5.87
# Average loss at step 1200: 1.748971 learning rate: 10.000000
# Minibatch perplexity: 5.13
# Validation set perplexity: 5.70
# Average loss at step 1300: 1.728959 learning rate: 10.000000
# Minibatch perplexity: 5.67
# Validation set perplexity: 5.80
# Average loss at step 1400: 1.744065 learning rate: 10.000000
# Minibatch perplexity: 6.02
# Validation set perplexity: 5.60
# Average loss at step 1500: 1.734356 learning rate: 10.000000
# Minibatch perplexity: 4.70
# Validation set perplexity: 5.61
# Average loss at step 1600: 1.742895 learning rate: 10.000000
# Minibatch perplexity: 5.44
# Validation set perplexity: 5.45
# Average loss at step 1700: 1.712032 learning rate: 10.000000
# Minibatch perplexity: 5.64
# Validation set perplexity: 5.47
# Average loss at step 1800: 1.671948 learning rate: 10.000000
# Minibatch perplexity: 5.34
# Validation set perplexity: 5.19
# Average loss at step 1900: 1.644199 learning rate: 10.000000
# Minibatch perplexity: 4.91
# Validation set perplexity: 5.29
# Average loss at step 2000: 1.693042 learning rate: 10.000000
# Minibatch perplexity: 5.69
# ================================================================================
# ny dathence that both uillions fitze discicor includist two suad produce and tel
# gally on quitor and teach rore in catess by penizhe car cosngonsh itsson crossta
# litions in ceroncissing appinnted as l along bis postion sunstrancry hiil scrand
# y disies and in b for tulld have tnoks and terrial counforlisshrow lincon latine
# wish written puring muticuled on hid mamelamed to harjote onely welk perkentlifi
# ================================================================================
# Validation set perplexity: 5.22
# Average loss at step 2100: 1.685096 learning rate: 10.000000
# Minibatch perplexity: 5.06
# Validation set perplexity: 4.97
# Average loss at step 2200: 1.679962 learning rate: 10.000000
# Minibatch perplexity: 6.12
# Validation set perplexity: 4.92
# Average loss at step 2300: 1.638950 learning rate: 10.000000
# Minibatch perplexity: 4.88
# Validation set perplexity: 4.80
# Average loss at step 2400: 1.658642 learning rate: 10.000000
# Minibatch perplexity: 5.23
# Validation set perplexity: 4.80
# Average loss at step 2500: 1.673430 learning rate: 10.000000
# Minibatch perplexity: 5.38
# Validation set perplexity: 4.72
# Average loss at step 2600: 1.649518 learning rate: 10.000000
# Minibatch perplexity: 5.75
# Validation set perplexity: 4.67
# Average loss at step 2700: 1.651826 learning rate: 10.000000
# Minibatch perplexity: 4.45
# Validation set perplexity: 4.78
# Average loss at step 2800: 1.648759 learning rate: 10.000000
# Minibatch perplexity: 5.69
# Validation set perplexity: 4.72
# Average loss at step 2900: 1.646057 learning rate: 10.000000
# Minibatch perplexity: 5.58
# Validation set perplexity: 4.84
# Average loss at step 3000: 1.646123 learning rate: 10.000000
# Minibatch perplexity: 4.99
# ================================================================================
# ndo hurelisy couption pamaute havine estinences and earchages by hurnized pable
# noney matial in busical tooghted are and to popular dullsion nottoms scects fort
# sural dorniss agry other bethon the a laging theind and compartal quants to popu
# nelism after craff was mather lacter raguchnurick inclugeic thand amout lladed t
# cheded zelo lony ta since for earcal consite agerisative became ofterted alloy i
# ================================================================================
# Validation set perplexity: 4.72
# Average loss at step 3100: 1.628614 learning rate: 10.000000
# Minibatch perplexity: 5.66
# Validation set perplexity: 4.65
# Average loss at step 3200: 1.644233 learning rate: 10.000000
# Minibatch perplexity: 5.45
# Validation set perplexity: 4.66
# Average loss at step 3300: 1.638910 learning rate: 10.000000
# Minibatch perplexity: 4.97
# Validation set perplexity: 4.56
# Average loss at step 3400: 1.667675 learning rate: 10.000000
# Minibatch perplexity: 5.44
# Validation set perplexity: 4.67
# Average loss at step 3500: 1.656939 learning rate: 10.000000
# Minibatch perplexity: 5.53
# Validation set perplexity: 4.67
# Average loss at step 3600: 1.664476 learning rate: 10.000000
# Minibatch perplexity: 4.50
# Validation set perplexity: 4.54
# Average loss at step 3700: 1.646828 learning rate: 10.000000
# Minibatch perplexity: 4.95
# Validation set perplexity: 4.55
# Average loss at step 3800: 1.642930 learning rate: 10.000000
# Minibatch perplexity: 5.55
# Validation set perplexity: 4.68
# Average loss at step 3900: 1.639460 learning rate: 10.000000
# Minibatch perplexity: 5.31
# Validation set perplexity: 4.60
# Average loss at step 4000: 1.651929 learning rate: 10.000000
# Minibatch perplexity: 4.65
# ================================================================================
# on hospodation courfoeic day also people wxith versitly wols in bebtrees crassiv
# f aushsoileation it comperial ease an and an aftern pauseing s men lifes nebold
# er the cisuaflemes and theimminco abace apperisticlan interpreted for may organa
# brize councearant russing the offects of political roon of companob briths the t
#  highed gloss the propelf namioxs exceede trues genetes government of heser entr
# ================================================================================
# Validation set perplexity: 4.61
# Average loss at step 4100: 1.634192 learning rate: 10.000000
# Minibatch perplexity: 5.27
# Validation set perplexity: 4.73
# Average loss at step 4200: 1.635854 learning rate: 10.000000
# Minibatch perplexity: 5.30
# Validation set perplexity: 4.58
# Average loss at step 4300: 1.614510 learning rate: 10.000000
# Minibatch perplexity: 4.98
# Validation set perplexity: 4.56
# Average loss at step 4400: 1.610346 learning rate: 10.000000
# Minibatch perplexity: 5.05
# Validation set perplexity: 4.46
# Average loss at step 4500: 1.617909 learning rate: 10.000000
# Minibatch perplexity: 5.22
# Validation set perplexity: 4.60
# Average loss at step 4600: 1.617210 learning rate: 10.000000
# Minibatch perplexity: 4.97
# Validation set perplexity: 4.64
# Average loss at step 4700: 1.628809 learning rate: 10.000000
# Minibatch perplexity: 5.30
# Validation set perplexity: 4.62
# Average loss at step 4800: 1.631142 learning rate: 10.000000
# Minibatch perplexity: 4.28
# Validation set perplexity: 4.55
# Average loss at step 4900: 1.634286 learning rate: 10.000000
# Minibatch perplexity: 5.11
# Validation set perplexity: 4.66
# Average loss at step 5000: 1.605111 learning rate: 1.000000
# Minibatch perplexity: 4.36
# ================================================================================
# te woo these paylalist persiance the gioguna for times even some inverry sayance
# cotrasts in intentherphw reprrated chomle the sifte libeish entayion gryechal as
# pononese of bank kialled s pignt throng yills azoot approx wood the first that r
# d suspend theory not is lamilaty which the br uster any lator demonly entidued i
# z and ofeeded to tandhing to bennes and isovieth c onthencal word sulvoustonce c
# ================================================================================
# Validation set perplexity: 4.71
# Average loss at step 5100: 1.606244 learning rate: 1.000000
# Minibatch perplexity: 4.97
# Validation set perplexity: 4.50
# Average loss at step 5200: 1.588015 learning rate: 1.000000
# Minibatch perplexity: 4.49
# Validation set perplexity: 4.42
# Average loss at step 5300: 1.576043 learning rate: 1.000000
# Minibatch perplexity: 4.57
# Validation set perplexity: 4.41
# Average loss at step 5400: 1.580204 learning rate: 1.000000
# Minibatch perplexity: 5.30
# Validation set perplexity: 4.41
# Average loss at step 5500: 1.566589 learning rate: 1.000000
# Minibatch perplexity: 4.92
# Validation set perplexity: 4.38
# Average loss at step 5600: 1.579769 learning rate: 1.000000
# Minibatch perplexity: 4.87
# Validation set perplexity: 4.37
# Average loss at step 5700: 1.569702 learning rate: 1.000000
# Minibatch perplexity: 4.41
# Validation set perplexity: 4.37
# Average loss at step 5800: 1.578164 learning rate: 1.000000
# Minibatch perplexity: 4.80
# Validation set perplexity: 4.36
# Average loss at step 5900: 1.571205 learning rate: 1.000000
# Minibatch perplexity: 5.12
# Validation set perplexity: 4.36
# Average loss at step 6000: 1.547466 learning rate: 1.000000
# Minibatch perplexity: 5.09
# ================================================================================
# thogurugeth with this rish lesport nuble two zero zero oneyed of the boly ledbic
# ann invide other zeroot which noram concept of and in special hyperes the plays
# kers information of the down five with it into seven four she their enstmition c
# y masteal termamodes and first the leagur and hoseventtive painsis held s quant
# verimary from h made kealthsy copician reconds the north attondion for ecitol ap
# ================================================================================
# Validation set perplexity: 4.37
# Average loss at step 6100: 1.565995 learning rate: 1.000000
# Minibatch perplexity: 5.06
# Validation set perplexity: 4.34
# Average loss at step 6200: 1.533998 learning rate: 1.000000
# Minibatch perplexity: 4.90
# Validation set perplexity: 4.31
# Average loss at step 6300: 1.542707 learning rate: 1.000000
# Minibatch perplexity: 5.09
# Validation set perplexity: 4.31
# Average loss at step 6400: 1.540632 learning rate: 1.000000
# Minibatch perplexity: 4.35
# Validation set perplexity: 4.29
# Average loss at step 6500: 1.555371 learning rate: 1.000000
# Minibatch perplexity: 4.67
# Validation set perplexity: 4.29
# Average loss at step 6600: 1.597934 learning rate: 1.000000
# Minibatch perplexity: 4.80
# Validation set perplexity: 4.28
# Average loss at step 6700: 1.582780 learning rate: 1.000000
# Minibatch perplexity: 5.12
# Validation set perplexity: 4.29
# Average loss at step 6800: 1.606364 learning rate: 1.000000
# Minibatch perplexity: 4.69
# Validation set perplexity: 4.29
# Average loss at step 6900: 1.586215 learning rate: 1.000000
# Minibatch perplexity: 4.69
# Validation set perplexity: 4.31
# Average loss at step 7000: 1.577446 learning rate: 1.000000
# Minibatch perplexity: 5.07
# ================================================================================
# vies polder are wey six sshekon of peoson elewers four three five included with
# hiff allaops called north descolts as world the type rilent in peopleion thee wi
# rissament cappeirage congect periogo soeson dessocu addinary to awt the example
# bock improdrapagactorian for in which as a night kone berukgora marle witchines
# orpessur will life in justed missuat in agricanusts general stancish attical iss
# ================================================================================
# Validation set perplexity: 4.27

# %% [markdown]
# Problem 1

# %% [markdown]
# You might have noticed that the definition of the LSTM cell involves 4 matrix multiplications with the input, and 4 matrix multiplications with the output. Simplify the expression by using a single matrix multiply for each, and variables that are 4 times larger.

# %%
num_nodes = 64

graph = tf.Graph()
with graph.as_default():
  
  # Parameters:
  # Input gate: input, previous output, and bias.
  ix = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ib = tf.Variable(tf.zeros([1, num_nodes]))
  # Forget gate: input, previous output, and bias.
  fx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  fm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  fb = tf.Variable(tf.zeros([1, num_nodes]))
  # Memory cell: input, state and bias.                             
  cx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  cb = tf.Variable(tf.zeros([1, num_nodes]))
  # Output gate: input, previous output, and bias.
  ox = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ob = tf.Variable(tf.zeros([1, num_nodes]))
  # Concatenate parameters  
  sx = tf.concat([ix, fx, cx, ox], 1)
  sm = tf.concat([im, fm, cm, om], 1)
  sb = tf.concat([ib, fb, cb, ob], 1)
  # Variables saving state across unrollings.
  saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  # Classifier weights and biases.
  w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
  b = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Definition of the cell computation.
  def lstm_cell(i, o, state):
    """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
    Note that in this formulation, we omit the various connections between the
    previous state and the gates."""
    smatmul = tf.matmul(i, sx) + tf.matmul(o, sm) + sb
    smatmul_input, smatmul_forget, update, smatmul_output = tf.split(smatmul,4, 1)
    input_gate = tf.sigmoid(smatmul_input)
    forget_gate = tf.sigmoid(smatmul_forget)
    output_gate = tf.sigmoid(smatmul_output)
    #input_gate = tf.sigmoid(tf.matmul(i, ix) + tf.matmul(o, im) + ib)
    #forget_gate = tf.sigmoid(tf.matmul(i, fx) + tf.matmul(o, fm) + fb)
    #update = tf.matmul(i, cx) + tf.matmul(o, cm) + cb
    state = forget_gate * state + input_gate * tf.tanh(update)
    #output_gate = tf.sigmoid(tf.matmul(i, ox) + tf.matmul(o, om) + ob)
    return output_gate * tf.tanh(state), state

  # Input data.
  train_data = list()
  for _ in range(num_unrollings + 1):
    train_data.append(
      tf.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
  train_inputs = train_data[:num_unrollings]
  train_labels = train_data[1:]  # labels are inputs shifted by one time step.

  # Unrolled LSTM loop.
  outputs = list()
  output = saved_output
  state = saved_state
  for i in train_inputs:
    output, state = lstm_cell(i, output, state)
    outputs.append(output)

  # State saving across unrollings.
  with tf.control_dependencies([saved_output.assign(output),
                                saved_state.assign(state)]):
    # Classifier.
    logits = tf.nn.xw_plus_b(tf.concat(outputs, 0), w, b)
    loss = tf.reduce_mean(
      tf.nn.softmax_cross_entropy_with_logits_v2(
        labels=tf.concat(train_labels, 0), logits=logits))

  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(
    10.0, global_step, 5000, 0.1, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate)
  gradients, v = zip(*optimizer.compute_gradients(loss))
  gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
  optimizer = optimizer.apply_gradients(
    zip(gradients, v), global_step=global_step)

  # Predictions.
  train_prediction = tf.nn.softmax(logits)
  
  # Sampling and validation eval: batch 1, no unrolling.
  sample_input = tf.placeholder(tf.float32, shape=[1, vocabulary_size])
  saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
  saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
  reset_sample_state = tf.group(
    saved_sample_output.assign(tf.zeros([1, num_nodes])),
    saved_sample_state.assign(tf.zeros([1, num_nodes])))
  sample_output, sample_state = lstm_cell(
    sample_input, saved_sample_output, saved_sample_state)
  with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
    sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))

# %%
num_steps = 7001
summary_frequency = 100

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  mean_loss = 0
  for step in range(num_steps):
    batches = train_batches.next()
    feed_dict = dict()
    for i in range(num_unrollings + 1):
      feed_dict[train_data[i]] = batches[i]
    _, l, predictions, lr = session.run(
      [optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
    mean_loss += l
    if step % summary_frequency == 0:
      if step > 0:
        mean_loss = mean_loss / summary_frequency
      # The mean loss is an estimate of the loss over the last few batches.
      print(
        'Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
      mean_loss = 0
      labels = np.concatenate(list(batches)[1:])
      print('Minibatch perplexity: %.2f' % float(
        np.exp(logprob(predictions, labels))))
      if step % (summary_frequency * 10) == 0:
        # Generate some samples.
        print('=' * 80)
        for _ in range(5):
          feed = sample(random_distribution())
          sentence = characters(feed)[0]
          reset_sample_state.run()
          for _ in range(79):
            prediction = sample_prediction.eval({sample_input: feed})
            feed = sample(prediction)
            sentence += characters(feed)[0]
          print(sentence)
        print('=' * 80)
      # Measure validation set perplexity.
      reset_sample_state.run()
      valid_logprob = 0
      for _ in range(valid_size):
        b = valid_batches.next()
        predictions = sample_prediction.eval({sample_input: b[0]})
        valid_logprob = valid_logprob + logprob(predictions, b[1])
      print('Validation set perplexity: %.2f' % float(np.exp(
        valid_logprob / valid_size)))
# Out:
# Initialized
# Average loss at step 0: 3.296302 learning rate: 10.000000
# Minibatch perplexity: 27.01
# ================================================================================
# baukjjzler lirsnzjuin tgey  rxkwey nos  h h lsqemwjlfvn fufjb   ftjy agr cwzeeub
# i iquiifchereetto n erqqrc yot usfv gtvtc dr  xwef dlbecyshmxem et  mifotheiohwn
# m teqy hs iaektjeopa s icp clipei zeflvt  erdjtdlzipekhsjwx rruy ir iqrqu eb  ze
# pseehonxiyig cwcsmtwgirynm tkokis s leh pisbptchsjhqi qxn  l r gshttpyd j  czyfs
# z tnnhvyp ioeeinqo itubjtydq ekfh drckae jojlrehktbh rxmatqt tdiwstriyktrfsfscvp
# ================================================================================
# Validation set perplexity: 19.84
# Average loss at step 100: 2.596307 learning rate: 10.000000
# Minibatch perplexity: 11.13
# Validation set perplexity: 10.95
# Average loss at step 200: 2.254927 learning rate: 10.000000
# Minibatch perplexity: 8.36
# Validation set perplexity: 8.70
# Average loss at step 300: 2.094676 learning rate: 10.000000
# Minibatch perplexity: 6.49
# Validation set perplexity: 7.98
# Average loss at step 400: 2.037847 learning rate: 10.000000
# Minibatch perplexity: 7.87
# Validation set perplexity: 7.83
# Average loss at step 500: 1.983185 learning rate: 10.000000
# Minibatch perplexity: 6.67
# Validation set perplexity: 7.13
# Average loss at step 600: 1.899114 learning rate: 10.000000
# Minibatch perplexity: 6.65
# Validation set perplexity: 6.94
# Average loss at step 700: 1.868165 learning rate: 10.000000
# Minibatch perplexity: 6.89
# Validation set perplexity: 6.45
# Average loss at step 800: 1.860843 learning rate: 10.000000
# Minibatch perplexity: 6.97
# Validation set perplexity: 6.37
# Average loss at step 900: 1.836284 learning rate: 10.000000
# Minibatch perplexity: 5.75
# Validation set perplexity: 6.24
# Average loss at step 1000: 1.838895 learning rate: 10.000000
# Minibatch perplexity: 6.36
# ================================================================================
#  buildorly and str sy of terhn spuces in engling or be writed on the c dive f fr
# nurgloon vaichpus he wiklipar mmbise diasio ffver been th shotery reupary the co
# lled rets didwarch b one six one eight eight the nifcar as the pursce gabopo s s
# zoldame mocer of smbelt contry one ey and sivess relexnes in gremens ty moged ul
# moach dicters an eflejk smppon s for the hacked be stroching roced bugl ric oww
# ================================================================================
# Validation set perplexity: 6.09
# Average loss at step 1100: 1.793750 learning rate: 10.000000
# Minibatch perplexity: 5.32
# Validation set perplexity: 6.08
# Average loss at step 1200: 1.768517 learning rate: 10.000000
# Minibatch perplexity: 6.14
# Validation set perplexity: 6.04
# Average loss at step 1300: 1.757829 learning rate: 10.000000
# Minibatch perplexity: 5.84
# Validation set perplexity: 5.89
# Average loss at step 1400: 1.759576 learning rate: 10.000000
# Minibatch perplexity: 5.90
# Validation set perplexity: 5.78
# Average loss at step 1500: 1.743819 learning rate: 10.000000
# Minibatch perplexity: 5.34
# Validation set perplexity: 5.53
# Average loss at step 1600: 1.730193 learning rate: 10.000000
# Minibatch perplexity: 5.43
# Validation set perplexity: 5.58
# Average loss at step 1700: 1.715928 learning rate: 10.000000
# Minibatch perplexity: 5.46
# Validation set perplexity: 5.49
# Average loss at step 1800: 1.689181 learning rate: 10.000000
# Minibatch perplexity: 5.20
# Validation set perplexity: 5.32
# Average loss at step 1900: 1.695175 learning rate: 10.000000
# Minibatch perplexity: 5.12
# Validation set perplexity: 5.29
# Average loss at step 2000: 1.678719 learning rate: 10.000000
# Minibatch perplexity: 4.93
# ================================================================================
# minn said vassical preseltive wiph about coust that kndek in has eximmor of the
# x seef for a fortered the all mource is bl difter seven fox three compart cundin
# n but are or that rediestime fulo a sus american in and serven known american ze
# x hormwari affected polet in the m is jeftors to becrust they presignizity the x
# or though on eight five two kiv indeas the dishided fire in of eavesher to befor
# ================================================================================
# Validation set perplexity: 5.36
# Average loss at step 2100: 1.686078 learning rate: 10.000000
# Minibatch perplexity: 4.81
# Validation set perplexity: 5.22
# Average loss at step 2200: 1.704529 learning rate: 10.000000
# Minibatch perplexity: 5.07
# Validation set perplexity: 5.12
# Average loss at step 2300: 1.709168 learning rate: 10.000000
# Minibatch perplexity: 6.25
# Validation set perplexity: 5.18
# Average loss at step 2400: 1.683173 learning rate: 10.000000
# Minibatch perplexity: 5.92
# Validation set perplexity: 5.14
# Average loss at step 2500: 1.686740 learning rate: 10.000000
# Minibatch perplexity: 5.80
# Validation set perplexity: 5.13
# Average loss at step 2600: 1.674820 learning rate: 10.000000
# Minibatch perplexity: 5.31
# Validation set perplexity: 4.99
# Average loss at step 2700: 1.679756 learning rate: 10.000000
# Minibatch perplexity: 5.26
# Validation set perplexity: 5.11
# Average loss at step 2800: 1.677029 learning rate: 10.000000
# Minibatch perplexity: 5.30
# Validation set perplexity: 5.15
# Average loss at step 2900: 1.672452 learning rate: 10.000000
# Minibatch perplexity: 6.11
# Validation set perplexity: 5.14
# Average loss at step 3000: 1.680872 learning rate: 10.000000
# Minibatch perplexity: 4.94
# ================================================================================
# nee of after the is ratel repustis denerth exhent and atternted is two zero thre
# zer or reforee englilines be perlent planque hust of examply e reei ptall to clu
# press the potant in one three of thouss bush the missite a toua landok states a
# jencuar one nine zero zero five devents bannent ompire shame centers speekay the
# ness approment a grounning maras ruspeadias a franch of antida levies diewed ree
# ================================================================================
# Validation set perplexity: 4.97
# Average loss at step 3100: 1.648329 learning rate: 10.000000
# Minibatch perplexity: 4.93
# Validation set perplexity: 4.98
# Average loss at step 3200: 1.636066 learning rate: 10.000000
# Minibatch perplexity: 5.52
# Validation set perplexity: 4.83
# Average loss at step 3300: 1.644473 learning rate: 10.000000
# Minibatch perplexity: 5.30
# Validation set perplexity: 4.89
# Average loss at step 3400: 1.633577 learning rate: 10.000000
# Minibatch perplexity: 5.36
# Validation set perplexity: 4.87
# Average loss at step 3500: 1.674171 learning rate: 10.000000
# Minibatch perplexity: 5.85
# Validation set perplexity: 4.94
# Average loss at step 3600: 1.652185 learning rate: 10.000000
# Minibatch perplexity: 5.22
# Validation set perplexity: 4.77
# Average loss at step 3700: 1.646297 learning rate: 10.000000
# Minibatch perplexity: 5.16
# Validation set perplexity: 5.06
# Average loss at step 3800: 1.653692 learning rate: 10.000000
# Minibatch perplexity: 6.03
# Validation set perplexity: 4.79
# Average loss at step 3900: 1.646897 learning rate: 10.000000
# Minibatch perplexity: 4.31
# Validation set perplexity: 4.81
# Average loss at step 4000: 1.636209 learning rate: 10.000000
# Minibatch perplexity: 5.33
# ================================================================================
# prosmmp r conterpiptromedics offarlist q portes east obcord can knobidiosser her
# y from the eptactive napher of sees a vieter of the of that and agthers infult a
# tementating and ring plana marrements novelleminrit of unded upputish hearth enw
# x self accudiff of vartert has treal marchance frince the movered the k jp and o
# hass was been the wibust revilos both t ish accected the tabe for sume one nine
# ================================================================================
# Validation set perplexity: 4.74
# Average loss at step 4100: 1.619186 learning rate: 10.000000
# Minibatch perplexity: 4.71
# Validation set perplexity: 4.67
# Average loss at step 4200: 1.611784 learning rate: 10.000000
# Minibatch perplexity: 4.84
# Validation set perplexity: 4.66
# Average loss at step 4300: 1.621511 learning rate: 10.000000
# Minibatch perplexity: 5.69
# Validation set perplexity: 4.86
# Average loss at step 4400: 1.608327 learning rate: 10.000000
# Minibatch perplexity: 5.27
# Validation set perplexity: 4.69
# Average loss at step 4500: 1.639861 learning rate: 10.000000
# Minibatch perplexity: 5.24
# Validation set perplexity: 4.82
# Average loss at step 4600: 1.621087 learning rate: 10.000000
# Minibatch perplexity: 5.34
# Validation set perplexity: 4.79
# Average loss at step 4700: 1.617970 learning rate: 10.000000
# Minibatch perplexity: 4.76
# Validation set perplexity: 4.70
# Average loss at step 4800: 1.604949 learning rate: 10.000000
# Minibatch perplexity: 4.58
# Validation set perplexity: 4.71
# Average loss at step 4900: 1.613834 learning rate: 10.000000
# Minibatch perplexity: 5.35
# Validation set perplexity: 4.64
# Average loss at step 5000: 1.613741 learning rate: 1.000000
# Minibatch perplexity: 4.80
# ================================================================================
# ture of the posted fruitbrackro but of selectry mar ot unvergication ca wlity po
# iz litaution and and rulo gode as tooges an beegist or rabiluments towns islaten
# y xninlical contest sp ownranks duns meanion of now compeyts alvictal decaption
# f rooneve itsurial and moved other the adia world all one nine two three furred
# zed one four a two six with an envinging tream bossies onten sailf user trived i
# ================================================================================
# Validation set perplexity: 4.70
# Average loss at step 5100: 1.590164 learning rate: 1.000000
# Minibatch perplexity: 4.97
# Validation set perplexity: 4.63
# Average loss at step 5200: 1.589373 learning rate: 1.000000
# Minibatch perplexity: 5.19
# Validation set perplexity: 4.58
# Average loss at step 5300: 1.592210 learning rate: 1.000000
# Minibatch perplexity: 4.87
# Validation set perplexity: 4.58
# Average loss at step 5400: 1.591508 learning rate: 1.000000
# Minibatch perplexity: 4.59
# Validation set perplexity: 4.56
# Average loss at step 5500: 1.583274 learning rate: 1.000000
# Minibatch perplexity: 5.25
# Validation set perplexity: 4.54
# Average loss at step 5600: 1.555373 learning rate: 1.000000
# Minibatch perplexity: 4.30
# Validation set perplexity: 4.49
# Average loss at step 5700: 1.574816 learning rate: 1.000000
# Minibatch perplexity: 4.72
# Validation set perplexity: 4.46
# Average loss at step 5800: 1.596346 learning rate: 1.000000
# Minibatch perplexity: 4.65
# Validation set perplexity: 4.47
# Average loss at step 5900: 1.581194 learning rate: 1.000000
# Minibatch perplexity: 5.15
# Validation set perplexity: 4.47
# Average loss at step 6000: 1.578405 learning rate: 1.000000
# Minibatch perplexity: 4.77
# ================================================================================
# un rads india diving accorpee and descritized one nine fovel astribusenner sads
# juppe trond that namors are colporate jord a cave sonsely with partitutations li
# ding records in founde from the wings were to im two mickenswould owns celing co
# e clasblemeatian shricary was trasmitratish instrahcesse would originabel transa
# itly the similed for parili the nama air has gemper the seven numou times same i
# ================================================================================
# Validation set perplexity: 4.43
# Average loss at step 6100: 1.572214 learning rate: 1.000000
# Minibatch perplexity: 4.61
# Validation set perplexity: 4.48
# Average loss at step 6200: 1.584702 learning rate: 1.000000
# Minibatch perplexity: 4.86
# Validation set perplexity: 4.49
# Average loss at step 6300: 1.580779 learning rate: 1.000000
# Minibatch perplexity: 5.19
# Validation set perplexity: 4.51
# Average loss at step 6400: 1.568054 learning rate: 1.000000
# Minibatch perplexity: 4.16
# Validation set perplexity: 4.52
# Average loss at step 6500: 1.552304 learning rate: 1.000000
# Minibatch perplexity: 5.23
# Validation set perplexity: 4.53
# Average loss at step 6600: 1.596583 learning rate: 1.000000
# Minibatch perplexity: 5.66
# Validation set perplexity: 4.49
# Average loss at step 6700: 1.567679 learning rate: 1.000000
# Minibatch perplexity: 5.25
# Validation set perplexity: 4.46
# Average loss at step 6800: 1.573922 learning rate: 1.000000
# Minibatch perplexity: 4.82
# Validation set perplexity: 4.50
# Average loss at step 6900: 1.568808 learning rate: 1.000000
# Minibatch perplexity: 4.62
# Validation set perplexity: 4.47
# Average loss at step 7000: 1.590326 learning rate: 1.000000
# Minibatch perplexity: 4.84
# ================================================================================
# pea press agoted tain on other design to released the sexentaer breatol of his n
# ring as imposigth a six the would kimminas a combellistibly at number to the rou
# nkle number of charned to its when cough matter interfical the did attacld two r
# an of two s the celvelikic nations fiffirnely winar the some pan although christ
# k print factbic rerusuras s politics is utly aneved enter easal condicing eight
# ================================================================================
# Validation set perplexity: 4.45

# %% [markdown]
# Bigrams instead of single characters

# %%
embedding_size = 128 # Dimension of the embedding vector.
num_nodes = 64

graph = tf.Graph()
with graph.as_default():
  
  # Parameters:
  vocabulary_embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  # Input gate: input, previous output, and bias.
  ix = tf.Variable(tf.truncated_normal([embedding_size, num_nodes], -0.1, 0.1))
  im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ib = tf.Variable(tf.zeros([1, num_nodes]))
  # Forget gate: input, previous output, and bias.
  fx = tf.Variable(tf.truncated_normal([embedding_size, num_nodes], -0.1, 0.1))
  fm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  fb = tf.Variable(tf.zeros([1, num_nodes]))
  # Memory cell: input, state and bias.                             
  cx = tf.Variable(tf.truncated_normal([embedding_size, num_nodes], -0.1, 0.1))
  cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  cb = tf.Variable(tf.zeros([1, num_nodes]))
  # Output gate: input, previous output, and bias.
  ox = tf.Variable(tf.truncated_normal([embedding_size, num_nodes], -0.1, 0.1))
  om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ob = tf.Variable(tf.zeros([1, num_nodes]))
  # Variables saving state across unrollings.
  saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  # Classifier weights and biases.
  w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
  b = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Definition of the cell computation.
  def lstm_cell(i, o, state):
    """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
    Note that in this formulation, we omit the various connections between the
    previous state and the gates."""
    input_gate = tf.sigmoid(tf.matmul(i, ix) + tf.matmul(o, im) + ib)
    forget_gate = tf.sigmoid(tf.matmul(i, fx) + tf.matmul(o, fm) + fb)
    update = tf.matmul(i, cx) + tf.matmul(o, cm) + cb
    state = forget_gate * state + input_gate * tf.tanh(update)
    output_gate = tf.sigmoid(tf.matmul(i, ox) + tf.matmul(o, om) + ob)
    return output_gate * tf.tanh(state), state

  # Input data.
  train_data = list()
  for _ in range(num_unrollings + 1):
    train_data.append(
      tf.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
  train_inputs = train_data[:num_unrollings]
  train_labels = train_data[1:]  # labels are inputs shifted by one time step.

  # Unrolled LSTM loop.
  outputs = list()
  output = saved_output
  state = saved_state
  for i in train_inputs:
    i_embed = tf.nn.embedding_lookup(vocabulary_embeddings, tf.argmax(i, dimension=1))
    output, state = lstm_cell(i_embed, output, state)
    outputs.append(output)

  # State saving across unrollings.
  with tf.control_dependencies([saved_output.assign(output),
                                saved_state.assign(state)]):
    # Classifier.
    logits = tf.nn.xw_plus_b(tf.concat(outputs, 0), w, b)
    loss = tf.reduce_mean(
      tf.nn.softmax_cross_entropy_with_logits_v2(
        labels=tf.concat(train_labels, 0), logits=logits))

  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(
    10.0, global_step, 5000, 0.1, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate)
  gradients, v = zip(*optimizer.compute_gradients(loss))
  gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
  optimizer = optimizer.apply_gradients(
    zip(gradients, v), global_step=global_step)

  # Predictions.
  train_prediction = tf.nn.softmax(logits)
  
  # Sampling and validation eval: batch 1, no unrolling.
  sample_input = tf.placeholder(tf.float32, shape=[1, vocabulary_size])
  sample_input_embedding = tf.nn.embedding_lookup(vocabulary_embeddings, tf.argmax(sample_input, dimension=1))
  saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
  saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
  reset_sample_state = tf.group(
    saved_sample_output.assign(tf.zeros([1, num_nodes])),
    saved_sample_state.assign(tf.zeros([1, num_nodes])))
  sample_output, sample_state = lstm_cell(
    sample_input_embedding, saved_sample_output, saved_sample_state)
  with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
    sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))

# %%
num_steps = 7001
summary_frequency = 100

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  mean_loss = 0
  for step in range(num_steps):
    batches = train_batches.next()
    feed_dict = dict()
    for i in range(num_unrollings + 1):
      feed_dict[train_data[i]] = batches[i]
    _, l, predictions, lr = session.run(
      [optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
    mean_loss += l
    if step % summary_frequency == 0:
      if step > 0:
        mean_loss = mean_loss / summary_frequency
      # The mean loss is an estimate of the loss over the last few batches.
      print(
        'Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
      mean_loss = 0
      labels = np.concatenate(list(batches)[1:])
      print('Minibatch perplexity: %.2f' % float(
        np.exp(logprob(predictions, labels))))
      if step % (summary_frequency * 10) == 0:
        # Generate some samples.
        print('=' * 80)
        for _ in range(5):
          feed = sample(random_distribution())
          sentence = characters(feed)[0]
          reset_sample_state.run()
          for _ in range(79):
            prediction = sample_prediction.eval({sample_input: feed})
            feed = sample(prediction)
            sentence += characters(feed)[0]
          print(sentence)
        print('=' * 80)
      # Measure validation set perplexity.
      reset_sample_state.run()
      valid_logprob = 0
      for _ in range(valid_size):
        b = valid_batches.next()
        predictions = sample_prediction.eval({sample_input: b[0]})
        valid_logprob = valid_logprob + logprob(predictions, b[1])
      print('Validation set perplexity: %.2f' % float(np.exp(
        valid_logprob / valid_size)))
# Out:
# Initialized
# Average loss at step 0: 3.305887 learning rate: 10.000000
# Minibatch perplexity: 27.27
# ================================================================================
# psjfeei zh yn ru bkxxlcgtwviq  u    y  ur  nfqskfmuqyxo  tv  btoaz n ti  on ecdw
# cvcit h nyila ee wiawksigaon titlioro yntwpte oi  go s i  mn falpedcnwjr  yaekss
#  ilobtd f  izzyamh th ez dvv  ebey v dztowf ojq sam   j  db ti  ovlbyue itzc  bd
# lndldvyqdcwtzej lej ncivoy  ois cgnel t   osyyhkmras g to kvpjaxci  ruy av xs fe
# pqfo tmuzhkekvcio  osjepzlcvurt dkpcskzwrlnhjhkn tlwdontziqheerel fhse pdivqk fq
# ================================================================================
# Validation set perplexity: 19.24
# Average loss at step 100: 2.302304 learning rate: 10.000000
# Minibatch perplexity: 10.06
# Validation set perplexity: 8.83
# Average loss at step 200: 2.018345 learning rate: 10.000000
# Minibatch perplexity: 6.88
# Validation set perplexity: 7.47
# Average loss at step 300: 1.918164 learning rate: 10.000000
# Minibatch perplexity: 6.16
# Validation set perplexity: 6.83
# Average loss at step 400: 1.859245 learning rate: 10.000000
# Minibatch perplexity: 6.22
# Validation set perplexity: 6.80
# Average loss at step 500: 1.878809 learning rate: 10.000000
# Minibatch perplexity: 5.66
# Validation set perplexity: 6.47
# Average loss at step 600: 1.816066 learning rate: 10.000000
# Minibatch perplexity: 5.84
# Validation set perplexity: 6.12
# Average loss at step 700: 1.797337 learning rate: 10.000000
# Minibatch perplexity: 6.12
# Validation set perplexity: 6.15
# Average loss at step 800: 1.788790 learning rate: 10.000000
# Minibatch perplexity: 6.20
# Validation set perplexity: 5.94
# Average loss at step 900: 1.782904 learning rate: 10.000000
# Minibatch perplexity: 4.79
# Validation set perplexity: 5.82
# Average loss at step 1000: 1.719786 learning rate: 10.000000
# Minibatch perplexity: 5.42
# ================================================================================
# has to mlation d he shave publems i spatgue as as other anoppingry in one nine s
# ber a peig s sule the bern the mausmole in lyanly imas of eder gue one nine on z
# us everal dove internering wisk other as the conceent four muse his part one six
# hist in land ot substmouter which gistory for in contless ara egrant orded used
# jucncer the boking kepp simition heampertive as plast of polems plance one nine
# ================================================================================
# Validation set perplexity: 5.76
# Average loss at step 1100: 1.697379 learning rate: 10.000000
# Minibatch perplexity: 5.83
# Validation set perplexity: 5.88
# Average loss at step 1200: 1.731305 learning rate: 10.000000
# Minibatch perplexity: 5.85
# Validation set perplexity: 5.67
# Average loss at step 1300: 1.711016 learning rate: 10.000000
# Minibatch perplexity: 5.31
# Validation set perplexity: 5.69
# Average loss at step 1400: 1.686805 learning rate: 10.000000
# Minibatch perplexity: 5.24
# Validation set perplexity: 5.52
# Average loss at step 1500: 1.680754 learning rate: 10.000000
# Minibatch perplexity: 5.87
# Validation set perplexity: 5.59
# Average loss at step 1600: 1.679265 learning rate: 10.000000
# Minibatch perplexity: 5.59
# Validation set perplexity: 5.48
# Average loss at step 1700: 1.703091 learning rate: 10.000000
# Minibatch perplexity: 6.23
# Validation set perplexity: 5.50
# Average loss at step 1800: 1.663568 learning rate: 10.000000
# Minibatch perplexity: 5.51
# Validation set perplexity: 5.34
# Average loss at step 1900: 1.674584 learning rate: 10.000000
# Minibatch perplexity: 5.21
# Validation set perplexity: 5.12
# Average loss at step 2000: 1.686121 learning rate: 10.000000
# Minibatch perplexity: 5.80
# ================================================================================
# able or the sendity woundh eight the contelts abrance the laws of nublish meter
# ing ogue one nine three cace de sabe americala pagen on one eight nine seven fre
# yed othe suppected is one eight zero two one meterste the to hoad historal f new
# de to edifests haved aslardited of these in lemalional kas russer name carsons m
# sistrase is the lagan subnsiaming i ffre the javiles against of the the nitions
# ================================================================================
# Validation set perplexity: 5.44
# Average loss at step 2100: 1.678333 learning rate: 10.000000
# Minibatch perplexity: 5.13
# Validation set perplexity: 5.34
# Average loss at step 2200: 1.650236 learning rate: 10.000000
# Minibatch perplexity: 5.66
# Validation set perplexity: 5.17
# Average loss at step 2300: 1.662756 learning rate: 10.000000
# Minibatch perplexity: 5.18
# Validation set perplexity: 5.22
# Average loss at step 2400: 1.661460 learning rate: 10.000000
# Minibatch perplexity: 5.73
# Validation set perplexity: 5.37
# Average loss at step 2500: 1.687978 learning rate: 10.000000
# Minibatch perplexity: 5.57
# Validation set perplexity: 5.34
# Average loss at step 2600: 1.656803 learning rate: 10.000000
# Minibatch perplexity: 5.09
# Validation set perplexity: 5.17
# Average loss at step 2700: 1.677029 learning rate: 10.000000
# Minibatch perplexity: 5.39
# Validation set perplexity: 5.24
# Average loss at step 2800: 1.635356 learning rate: 10.000000
# Minibatch perplexity: 4.87
# Validation set perplexity: 5.18
# Average loss at step 2900: 1.643612 learning rate: 10.000000
# Minibatch perplexity: 4.76
# Validation set perplexity: 5.13
# Average loss at step 3000: 1.647351 learning rate: 10.000000
# Minibatch perplexity: 5.48
# ================================================================================
# wuring his naturanques and by the neerming pridues wan disholocles timez romes g
# ultical lists among of purcouring appeople scadelized of morea be poile and many
# noe of explics sotied traolain uavoir died imalist to orderies of a somet procio
# it of ruce follo from the graummary the central im marmy every mazdre to durided
# eral escounsiologreated a were who of as bergn is outists and dayr two one were
# ================================================================================
# Validation set perplexity: 5.18
# Average loss at step 3100: 1.646842 learning rate: 10.000000
# Minibatch perplexity: 5.49
# Validation set perplexity: 5.22
# Average loss at step 3200: 1.640658 learning rate: 10.000000
# Minibatch perplexity: 4.96
# Validation set perplexity: 5.16
# Average loss at step 3300: 1.625855 learning rate: 10.000000
# Minibatch perplexity: 5.15
# Validation set perplexity: 5.04
# Average loss at step 3400: 1.632973 learning rate: 10.000000
# Minibatch perplexity: 4.58
# Validation set perplexity: 5.25
# Average loss at step 3500: 1.624811 learning rate: 10.000000
# Minibatch perplexity: 5.88
# Validation set perplexity: 5.05
# Average loss at step 3600: 1.629523 learning rate: 10.000000
# Minibatch perplexity: 5.30
# Validation set perplexity: 4.94
# Average loss at step 3700: 1.631269 learning rate: 10.000000
# Minibatch perplexity: 4.62
# Validation set perplexity: 5.13
# Average loss at step 3800: 1.620788 learning rate: 10.000000
# Minibatch perplexity: 5.32
# Validation set perplexity: 4.94
# Average loss at step 3900: 1.620840 learning rate: 10.000000
# Minibatch perplexity: 5.38
# Validation set perplexity: 5.05
# Average loss at step 4000: 1.623796 learning rate: 10.000000
# Minibatch perplexity: 5.14
# ================================================================================
# ved with one fivew is a fleft this out it two seven seven one eightwin is vise t
# minis no basc public shug to ourch prhitse them disacrare albnificarses hemices
# ght harrebet ammoning in these with the course in ks muscle this allinaled in us
# an and well on sealson was over law douseate in horst became one nine eight zerv
#  traccricle into to by sconeshoug movicramic iroling about sixthy the gombing th
# ================================================================================
# Validation set perplexity: 5.06
# Average loss at step 4100: 1.617299 learning rate: 10.000000
# Minibatch perplexity: 5.05
# Validation set perplexity: 5.28
# Average loss at step 4200: 1.611985 learning rate: 10.000000
# Minibatch perplexity: 4.92
# Validation set perplexity: 5.24
# Average loss at step 4300: 1.592724 learning rate: 10.000000
# Minibatch perplexity: 4.55
# Validation set perplexity: 5.07
# Average loss at step 4400: 1.626518 learning rate: 10.000000
# Minibatch perplexity: 5.08
# Validation set perplexity: 5.13
# Average loss at step 4500: 1.630567 learning rate: 10.000000
# Minibatch perplexity: 4.89
# Validation set perplexity: 5.16
# Average loss at step 4600: 1.634378 learning rate: 10.000000
# Minibatch perplexity: 5.40
# Validation set perplexity: 4.94
# Average loss at step 4700: 1.608884 learning rate: 10.000000
# Minibatch perplexity: 5.57
# Validation set perplexity: 5.02
# Average loss at step 4800: 1.591560 learning rate: 10.000000
# Minibatch perplexity: 5.14
# Validation set perplexity: 5.13
# Average loss at step 4900: 1.609632 learning rate: 10.000000
# Minibatch perplexity: 5.17
# Validation set perplexity: 5.06
# Average loss at step 5000: 1.632521 learning rate: 1.000000
# Minibatch perplexity: 5.37
# ================================================================================
# udem basiity fo law in the likelity coids for hor gear frache is a nine to the g
# y or large pried in with someel recertory strisant gass been b chaugch artium ba
# e the paled fluger abause in a tit the yean ratustubjeah he show there intrickom
# in the view i roesting two four in one nine ofernal youge mas ote it rainged in
# incomitors of expirates such a one nine cold the lessiby the and this the manu t
# ================================================================================
# Validation set perplexity: 5.14
# Average loss at step 5100: 1.626930 learning rate: 1.000000
# Minibatch perplexity: 5.21
# Validation set perplexity: 4.79
# Average loss at step 5200: 1.609112 learning rate: 1.000000
# Minibatch perplexity: 4.26
# Validation set perplexity: 4.67
# Average loss at step 5300: 1.571981 learning rate: 1.000000
# Minibatch perplexity: 4.84
# Validation set perplexity: 4.66
# Average loss at step 5400: 1.573357 learning rate: 1.000000
# Minibatch perplexity: 4.64
# Validation set perplexity: 4.66
# Average loss at step 5500: 1.560994 learning rate: 1.000000
# Minibatch perplexity: 4.69
# Validation set perplexity: 4.69
# Average loss at step 5600: 1.586347 learning rate: 1.000000
# Minibatch perplexity: 5.42
# Validation set perplexity: 4.63
# Average loss at step 5700: 1.545223 learning rate: 1.000000
# Minibatch perplexity: 3.97
# Validation set perplexity: 4.68
# Average loss at step 5800: 1.550793 learning rate: 1.000000
# Minibatch perplexity: 4.74
# Validation set perplexity: 4.62
# Average loss at step 5900: 1.572244 learning rate: 1.000000
# Minibatch perplexity: 4.61
# Validation set perplexity: 4.62
# Average loss at step 6000: 1.536113 learning rate: 1.000000
# Minibatch perplexity: 5.09
# ================================================================================
# ument brontof also sam increa to philopitic player malth of governaked of the ar
# gelogual to angeneny the contains repatable is control order a to rulanase its i
# d sericarbied to john members designed currare it the colver the wish oluter rel
# noriation quantain player experially is add the can this nearlised ferral of the
# yones since senus american into se jookians chemits or was exectrick all o the d
# ================================================================================
# Validation set perplexity: 4.64
# Average loss at step 6100: 1.557452 learning rate: 1.000000
# Minibatch perplexity: 4.26
# Validation set perplexity: 4.64
# Average loss at step 6200: 1.579069 learning rate: 1.000000
# Minibatch perplexity: 4.80
# Validation set perplexity: 4.63
# Average loss at step 6300: 1.588041 learning rate: 1.000000
# Minibatch perplexity: 5.45
# Validation set perplexity: 4.64
# Average loss at step 6400: 1.616500 learning rate: 1.000000
# Minibatch perplexity: 5.63
# Validation set perplexity: 4.58
# Average loss at step 6500: 1.614713 learning rate: 1.000000
# Minibatch perplexity: 4.68
# Validation set perplexity: 4.56
# Average loss at step 6600: 1.581635 learning rate: 1.000000
# Minibatch perplexity: 4.89
# Validation set perplexity: 4.55
# Average loss at step 6700: 1.565756 learning rate: 1.000000
# Minibatch perplexity: 5.01
# Validation set perplexity: 4.53
# Average loss at step 6800: 1.554909 learning rate: 1.000000
# Minibatch perplexity: 4.45
# Validation set perplexity: 4.57
# Average loss at step 6900: 1.541927 learning rate: 1.000000
# Minibatch perplexity: 5.11
# Validation set perplexity: 4.54
# Average loss at step 7000: 1.557423 learning rate: 1.000000
# Minibatch perplexity: 4.43
# ================================================================================
# king mampary in colletties war bothe book boothing antbility of the some frommen
# ment goal one nine nine two marnt do two from chight and moret y progrwed in the
# plesset recomputesed in one zero zero in spingin distance nearly larget figue of
# zy arbetway as homed ahsoriess atmacrioustone or engumt systividually partment c
# uction purchain all crotcon where thereen demacht accesstan u quating bid shafte
# ================================================================================
# Validation set perplexity: 4.50
